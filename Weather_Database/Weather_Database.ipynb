# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adrar
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | port macquarie
# Processing Record 4 of Set 1 | colac
# Processing Record 5 of Set 1 | kieta
# Processing Record 6 of Set 1 | bathsheba
# Processing Record 7 of Set 1 | letlhakane
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | bokhan
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | lorengau
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | rapid valley
# Processing Record 20 of Set 1 | bilibino
# Processing Record 21 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 1 | herzberg
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | keti bandar
# Processing Record 25 of Set 1 | bluff
# Processing Record 26 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 1 | kishi
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | mitsamiouli
# Processing Record 33 of Set 1 | nishihara
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | nizwa
# Processing Record 38 of Set 1 | kourou
# Processing Record 39 of Set 1 | batticaloa
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | magadan
# Processing Record 42 of Set 1 | boca del monte
# Processing Record 43 of Set 1 | llanes
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | altar
# Processing Record 46 of Set 1 | westport
# Processing Record 47 of Set 1 | camopi
# Processing Record 48 of Set 1 | seoul
# Processing Record 49 of Set 1 | jalu
# Processing Record 50 of Set 1 | whyalla
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | aklavik
# Processing Record 3 of Set 2 | smithers
# Processing Record 4 of Set 2 | irbil
# Processing Record 5 of Set 2 | diplo
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | salinas
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | aloleng
# Processing Record 11 of Set 2 | maputo
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | lensk
# Processing Record 16 of Set 2 | lodwar
# Processing Record 17 of Set 2 | mandalgovi
# Processing Record 18 of Set 2 | alghero
# Processing Record 19 of Set 2 | kulhudhuffushi
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | marystown
# Processing Record 22 of Set 2 | mataura
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | padang
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | shumikha
# Processing Record 27 of Set 2 | tabory
# Processing Record 28 of Set 2 | harper
# Processing Record 29 of Set 2 | jamestown
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | honiara
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | ahipara
# Processing Record 34 of Set 2 | kaseda
# Processing Record 35 of Set 2 | katsuura
# Processing Record 36 of Set 2 | malakal
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | nicoya
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | saldanha
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | mahebourg
# Processing Record 46 of Set 2 | alto araguaia
# Processing Record 47 of Set 2 | te anau
# Processing Record 48 of Set 2 | valparaiso
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | sfantu gheorghe
# Processing Record 1 of Set 3 | karpogory
# Processing Record 2 of Set 3 | eyl
# Processing Record 3 of Set 3 | altay
# Processing Record 4 of Set 3 | tonstad
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | saint george
# Processing Record 7 of Set 3 | chuy
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | bengkulu
# Processing Record 11 of Set 3 | egvekinot
# Processing Record 12 of Set 3 | komsomolskiy
# Processing Record 13 of Set 3 | ruteng
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | praia
# Processing Record 16 of Set 3 | yaan
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | northam
# Processing Record 19 of Set 3 | bonavista
# Processing Record 20 of Set 3 | metro
# Processing Record 21 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 22 of Set 3 | sechura
# Processing Record 23 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 3 | cooma
# Processing Record 25 of Set 3 | octeville
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | saint anthony
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | banikoara
# Processing Record 31 of Set 3 | cabedelo
# Processing Record 32 of Set 3 | nizhniy kuranakh
# Processing Record 33 of Set 3 | irbit
# Processing Record 34 of Set 3 | qui nhon
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | baykit
# Processing Record 37 of Set 3 | ixtapa
# Processing Record 38 of Set 3 | turi
# Processing Record 39 of Set 3 | porto velho
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | tadine
# Processing Record 42 of Set 3 | zemio
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | port-gentil
# Processing Record 45 of Set 3 | alyangula
# Processing Record 46 of Set 3 | davila
# Processing Record 47 of Set 3 | taboshar
# Processing Record 48 of Set 3 | acarau
# Processing Record 49 of Set 3 | grand baie
# Processing Record 50 of Set 3 | clyde river
# Processing Record 1 of Set 4 | union
# Processing Record 2 of Set 4 | saint-augustin
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | ngunguru
# Processing Record 5 of Set 4 | los llanos de aridane
# Processing Record 6 of Set 4 | bukama
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | choma
# Processing Record 9 of Set 4 | mikkeli
# Processing Record 10 of Set 4 | cherskiy
# Processing Record 11 of Set 4 | drummondville
# Processing Record 12 of Set 4 | boguchany
# Processing Record 13 of Set 4 | olga
# Processing Record 14 of Set 4 | foz do iguacu
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | khatanga
# Processing Record 17 of Set 4 | nome
# Processing Record 18 of Set 4 | uroteppa
# City not found. Skipping...
# Processing Record 19 of Set 4 | acuna
# City not found. Skipping...
# Processing Record 20 of Set 4 | brainerd
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | angoche
# Processing Record 23 of Set 4 | yar-sale
# Processing Record 24 of Set 4 | mayo
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | cap malheureux
# Processing Record 27 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 4 | zharkent
# Processing Record 29 of Set 4 | lavrentiya
# Processing Record 30 of Set 4 | waipawa
# Processing Record 31 of Set 4 | geraldton
# Processing Record 32 of Set 4 | lufilufi
# Processing Record 33 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 4 | flin flon
# Processing Record 35 of Set 4 | lar
# Processing Record 36 of Set 4 | aldan
# Processing Record 37 of Set 4 | oum hadjer
# Processing Record 38 of Set 4 | tilichiki
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | ha giang
# Processing Record 41 of Set 4 | palmer
# Processing Record 42 of Set 4 | hambantota
# Processing Record 43 of Set 4 | parintins
# Processing Record 44 of Set 4 | portland
# Processing Record 45 of Set 4 | busselton
# Processing Record 46 of Set 4 | kaitangata
# Processing Record 47 of Set 4 | havoysund
# Processing Record 48 of Set 4 | kavieng
# Processing Record 49 of Set 4 | pitea
# Processing Record 50 of Set 4 | hobyo
# Processing Record 1 of Set 5 | ormara
# Processing Record 2 of Set 5 | pandharpur
# Processing Record 3 of Set 5 | kiama
# Processing Record 4 of Set 5 | houma
# Processing Record 5 of Set 5 | pimentel
# Processing Record 6 of Set 5 | olafsvik
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | sulmona
# Processing Record 9 of Set 5 | narwana
# Processing Record 10 of Set 5 | tiarei
# Processing Record 11 of Set 5 | jinchang
# Processing Record 12 of Set 5 | xichang
# Processing Record 13 of Set 5 | chernyshevsk
# Processing Record 14 of Set 5 | atar
# Processing Record 15 of Set 5 | poronaysk
# Processing Record 16 of Set 5 | otradnoye
# Processing Record 17 of Set 5 | manavalakurichi
# Processing Record 18 of Set 5 | bairiki
# Processing Record 19 of Set 5 | eureka
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 5 | labuhan
# Processing Record 24 of Set 5 | eisenberg
# Processing Record 25 of Set 5 | san cristobal
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | santa cruz de tenerife
# Processing Record 28 of Set 5 | makakilo city
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | gamba
# Processing Record 31 of Set 5 | koungou
# Processing Record 32 of Set 5 | ramhormoz
# Processing Record 33 of Set 5 | naze
# Processing Record 34 of Set 5 | nantucket
# Processing Record 35 of Set 5 | port hedland
# Processing Record 36 of Set 5 | dodge city
# Processing Record 37 of Set 5 | corrientes
# Processing Record 38 of Set 5 | saskylakh
# Processing Record 39 of Set 5 | murgab
# Processing Record 40 of Set 5 | tessalit
# Processing Record 41 of Set 5 | buchanan
# Processing Record 42 of Set 5 | beyneu
# Processing Record 43 of Set 5 | straumen
# Processing Record 44 of Set 5 | methoni
# Processing Record 45 of Set 5 | borgarnes
# Processing Record 46 of Set 5 | balkhash
# Processing Record 47 of Set 5 | amapa
# Processing Record 48 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 5 | atambua
# Processing Record 50 of Set 5 | rochegda
# Processing Record 1 of Set 6 | mizan teferi
# Processing Record 2 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 6 | urumqi
# Processing Record 4 of Set 6 | lebu
# Processing Record 5 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 6 | salalah
# Processing Record 7 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 8 of Set 6 | williams lake
# Processing Record 9 of Set 6 | codrington
# Processing Record 10 of Set 6 | ocampo
# Processing Record 11 of Set 6 | klaksvik
# Processing Record 12 of Set 6 | kholtoson
# Processing Record 13 of Set 6 | palaia fokaia
# Processing Record 14 of Set 6 | port hardy
# Processing Record 15 of Set 6 | bawku
# Processing Record 16 of Set 6 | korla
# Processing Record 17 of Set 6 | san quintin
# Processing Record 18 of Set 6 | toyo
# Processing Record 19 of Set 6 | kahului
# Processing Record 20 of Set 6 | beira
# Processing Record 21 of Set 6 | broken hill
# Processing Record 22 of Set 6 | presidente medici
# Processing Record 23 of Set 6 | nabire
# Processing Record 24 of Set 6 | am timan
# Processing Record 25 of Set 6 | richards bay
# Processing Record 26 of Set 6 | inirida
# Processing Record 27 of Set 6 | ewa beach
# Processing Record 28 of Set 6 | japura
# Processing Record 29 of Set 6 | goure
# Processing Record 30 of Set 6 | verkhnyaya inta
# Processing Record 31 of Set 6 | pisco
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | san jeronimo
# Processing Record 34 of Set 6 | provideniya
# Processing Record 35 of Set 6 | ostrovnoy
# Processing Record 36 of Set 6 | sibolga
# Processing Record 37 of Set 6 | tianpeng
# Processing Record 38 of Set 6 | urfa
# City not found. Skipping...
# Processing Record 39 of Set 6 | athabasca
# Processing Record 40 of Set 6 | moree
# Processing Record 41 of Set 6 | ketchikan
# Processing Record 42 of Set 6 | lata
# Processing Record 43 of Set 6 | mohacs
# Processing Record 44 of Set 6 | dzhebariki-khaya
# Processing Record 45 of Set 6 | la ronge
# Processing Record 46 of Set 6 | pregradnaya
# Processing Record 47 of Set 6 | tumpat
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | nizhniy tsasuchey
# Processing Record 50 of Set 6 | iqaluit
# Processing Record 1 of Set 7 | muncar
# Processing Record 2 of Set 7 | lokoja
# Processing Record 3 of Set 7 | vestmannaeyjar
# Processing Record 4 of Set 7 | honolulu
# Processing Record 5 of Set 7 | tooele
# Processing Record 6 of Set 7 | dabat
# Processing Record 7 of Set 7 | ulagan
# Processing Record 8 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 9 of Set 7 | bac giang
# Processing Record 10 of Set 7 | andros town
# Processing Record 11 of Set 7 | kharitonovo
# Processing Record 12 of Set 7 | agboville
# Processing Record 13 of Set 7 | yarim
# Processing Record 14 of Set 7 | san juan
# Processing Record 15 of Set 7 | tabou
# Processing Record 16 of Set 7 | evans
# Processing Record 17 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | baruun-urt
# Processing Record 20 of Set 7 | vila franca do campo
# Processing Record 21 of Set 7 | belur
# Processing Record 22 of Set 7 | sao felix do xingu
# Processing Record 23 of Set 7 | nago
# Processing Record 24 of Set 7 | aquiraz
# Processing Record 25 of Set 7 | vidim
# Processing Record 26 of Set 7 | sugal
# Processing Record 27 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 7 | crib point
# Processing Record 29 of Set 7 | rawson
# Processing Record 30 of Set 7 | yulara
# Processing Record 31 of Set 7 | punaauia
# Processing Record 32 of Set 7 | north bend
# Processing Record 33 of Set 7 | ponta delgada
# Processing Record 34 of Set 7 | salvador
# Processing Record 35 of Set 7 | mokhotlong
# Processing Record 36 of Set 7 | ajdabiya
# Processing Record 37 of Set 7 | sobolevo
# Processing Record 38 of Set 7 | souillac
# Processing Record 39 of Set 7 | severo-kurilsk
# Processing Record 40 of Set 7 | asadabad
# Processing Record 41 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 7 | sharjah
# Processing Record 43 of Set 7 | jacareacanga
# Processing Record 44 of Set 7 | catuday
# Processing Record 45 of Set 7 | huarmey
# Processing Record 46 of Set 7 | avera
# Processing Record 47 of Set 7 | sitka
# Processing Record 48 of Set 7 | sao joao da barra
# Processing Record 49 of Set 7 | port shepstone
# Processing Record 50 of Set 7 | homer
# Processing Record 1 of Set 8 | terrace bay
# Processing Record 2 of Set 8 | vardo
# Processing Record 3 of Set 8 | banda aceh
# Processing Record 4 of Set 8 | asyut
# Processing Record 5 of Set 8 | belmonte
# Processing Record 6 of Set 8 | east london
# Processing Record 7 of Set 8 | whitehorse
# Processing Record 8 of Set 8 | beian
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | autlan
# City not found. Skipping...
# Processing Record 11 of Set 8 | brokopondo
# Processing Record 12 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 8 | alofi
# Processing Record 14 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 8 | saint-georges
# Processing Record 16 of Set 8 | sioux lookout
# Processing Record 17 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 18 of Set 8 | manado
# Processing Record 19 of Set 8 | samarai
# Processing Record 20 of Set 8 | ayorou
# Processing Record 21 of Set 8 | neepawa
# Processing Record 22 of Set 8 | conceicao do araguaia
# Processing Record 23 of Set 8 | kurilsk
# Processing Record 24 of Set 8 | vao
# Processing Record 25 of Set 8 | esperance
# Processing Record 26 of Set 8 | zhigansk
# Processing Record 27 of Set 8 | yagodnoye
# Processing Record 28 of Set 8 | meulaboh
# Processing Record 29 of Set 8 | raga
# Processing Record 30 of Set 8 | guerrero negro
# Processing Record 31 of Set 8 | vernon
# Processing Record 32 of Set 8 | ust-kuyga
# Processing Record 33 of Set 8 | cuamba
# Processing Record 34 of Set 8 | pangai
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | luderitz
# Processing Record 37 of Set 8 | cururupu
# Processing Record 38 of Set 8 | moerai
# Processing Record 39 of Set 8 | isangel
# Processing Record 40 of Set 8 | namibe
# Processing Record 41 of Set 8 | marsaxlokk
# Processing Record 42 of Set 8 | hasaki
# Processing Record 43 of Set 8 | caravelas
# Processing Record 44 of Set 8 | bambanglipuro
# Processing Record 45 of Set 8 | hearst
# Processing Record 46 of Set 8 | lenggries
# Processing Record 47 of Set 8 | soyo
# Processing Record 48 of Set 8 | fukue
# Processing Record 49 of Set 8 | los algarrobos
# Processing Record 50 of Set 8 | chipinge
# Processing Record 1 of Set 9 | thinadhoo
# Processing Record 2 of Set 9 | champerico
# Processing Record 3 of Set 9 | luganville
# Processing Record 4 of Set 9 | zabid
# Processing Record 5 of Set 9 | gallup
# Processing Record 6 of Set 9 | aksu
# Processing Record 7 of Set 9 | conde
# Processing Record 8 of Set 9 | brae
# Processing Record 9 of Set 9 | ilovlya
# Processing Record 10 of Set 9 | pemba
# Processing Record 11 of Set 9 | tilsonburg
# City not found. Skipping...
# Processing Record 12 of Set 9 | aurich
# Processing Record 13 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 9 | kerema
# Processing Record 15 of Set 9 | montague
# Processing Record 16 of Set 9 | burias
# Processing Record 17 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 9 | manzhouli
# Processing Record 19 of Set 9 | kalmunai
# Processing Record 20 of Set 9 | kumluca
# Processing Record 21 of Set 9 | coquimbo
# Processing Record 22 of Set 9 | santa maria
# Processing Record 23 of Set 9 | ust-maya
# Processing Record 24 of Set 9 | half moon bay
# Processing Record 25 of Set 9 | port blair
# Processing Record 26 of Set 9 | hami
# Processing Record 27 of Set 9 | auki
# Processing Record 28 of Set 9 | alice springs
# Processing Record 29 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 30 of Set 9 | evensk
# Processing Record 31 of Set 9 | yumen
# Processing Record 32 of Set 9 | tezu
# Processing Record 33 of Set 9 | lasem
# Processing Record 34 of Set 9 | chabahar
# Processing Record 35 of Set 9 | batagay-alyta
# Processing Record 36 of Set 9 | georgetown
# Processing Record 37 of Set 9 | krasnyy kholm
# Processing Record 38 of Set 9 | onda
# Processing Record 39 of Set 9 | bonaventure
# Processing Record 40 of Set 9 | awbari
# Processing Record 41 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 42 of Set 9 | aleksandrov gay
# Processing Record 43 of Set 9 | beaufort
# Processing Record 44 of Set 9 | black river
# Processing Record 45 of Set 9 | kudinovo
# Processing Record 46 of Set 9 | boa vista
# Processing Record 47 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 9 | teofilo otoni
# Processing Record 49 of Set 9 | pombas
# Processing Record 50 of Set 9 | kaeo
# Processing Record 1 of Set 10 | beinamar
# Processing Record 2 of Set 10 | palestine
# Processing Record 3 of Set 10 | camacha
# Processing Record 4 of Set 10 | haines junction
# Processing Record 5 of Set 10 | burns lake
# Processing Record 6 of Set 10 | kargil
# Processing Record 7 of Set 10 | laguna
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 10 | mayumba
# Processing Record 11 of Set 10 | hwange
# Processing Record 12 of Set 10 | bud
# Processing Record 13 of Set 10 | rio bravo
# Processing Record 14 of Set 10 | dabeiba
# Processing Record 15 of Set 10 | aurangabad
# Processing Record 16 of Set 10 | fairbanks
# Processing Record 17 of Set 10 | margate
# Processing Record 18 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 19 of Set 10 | fougamou
# Processing Record 20 of Set 10 | kavaratti
# Processing Record 21 of Set 10 | ouegoa
# Processing Record 22 of Set 10 | manuk mangkaw
# Processing Record 23 of Set 10 | praia da vitoria
# Processing Record 24 of Set 10 | nemuro
# Processing Record 25 of Set 10 | sinnamary
# Processing Record 26 of Set 10 | kashan
# Processing Record 27 of Set 10 | barcelos
# Processing Record 28 of Set 10 | zhangye
# Processing Record 29 of Set 10 | faanui
# Processing Record 30 of Set 10 | ozu
# Processing Record 31 of Set 10 | mozarlandia
# Processing Record 32 of Set 10 | hualmay
# Processing Record 33 of Set 10 | kloulklubed
# Processing Record 34 of Set 10 | cabo san lucas
# Processing Record 35 of Set 10 | touros
# Processing Record 36 of Set 10 | fukuma
# Processing Record 37 of Set 10 | arkhonskaya
# Processing Record 38 of Set 10 | martinsville
# Processing Record 39 of Set 10 | careiro da varzea
# Processing Record 40 of Set 10 | flinders
# Processing Record 41 of Set 10 | comodoro rivadavia
# Processing Record 42 of Set 10 | supe
# Processing Record 43 of Set 10 | riachao das neves
# Processing Record 44 of Set 10 | dingle
# Processing Record 45 of Set 10 | poum
# Processing Record 46 of Set 10 | burnie
# Processing Record 47 of Set 10 | luau
# Processing Record 48 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 10 | vedaranniyam
# City not found. Skipping...
# Processing Record 50 of Set 10 | aksarka
# Processing Record 1 of Set 11 | grindavik
# Processing Record 2 of Set 11 | sola
# Processing Record 3 of Set 11 | kathu
# Processing Record 4 of Set 11 | mount pleasant
# Processing Record 5 of Set 11 | akyab
# Processing Record 6 of Set 11 | shibetsu
# Processing Record 7 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 11 | beloha
# Processing Record 9 of Set 11 | tommot
# Processing Record 10 of Set 11 | verkhnevilyuysk
# Processing Record 11 of Set 11 | norsup
# Processing Record 12 of Set 11 | gondanglegi
# Processing Record 13 of Set 11 | wattegama
# Processing Record 14 of Set 11 | kenora
# Processing Record 15 of Set 11 | lucea
# Processing Record 16 of Set 11 | yining
# Processing Record 17 of Set 11 | andenes
# Processing Record 18 of Set 11 | vanavara
# Processing Record 19 of Set 11 | sarkand
# Processing Record 20 of Set 11 | lagoa
# Processing Record 21 of Set 11 | villazon
# Processing Record 22 of Set 11 | san vicente
# Processing Record 23 of Set 11 | magadi
# Processing Record 24 of Set 11 | barranca
# Processing Record 25 of Set 11 | opuwo
# Processing Record 26 of Set 11 | moron
# Processing Record 27 of Set 11 | boundiali
# Processing Record 28 of Set 11 | kidal
# Processing Record 29 of Set 11 | colares
# Processing Record 30 of Set 11 | hochstadt
# Processing Record 31 of Set 11 | naryan-mar
# Processing Record 32 of Set 11 | havelock
# Processing Record 33 of Set 11 | lalibela
# Processing Record 34 of Set 11 | bacong
# Processing Record 35 of Set 11 | muros
# Processing Record 36 of Set 11 | panalingaan
# Processing Record 37 of Set 11 | vostok
# Processing Record 38 of Set 11 | plaster rock
# Processing Record 39 of Set 11 | constitucion
# Processing Record 40 of Set 11 | chesma
# Processing Record 41 of Set 11 | chulman
# Processing Record 42 of Set 11 | zhangjiakou
# Processing Record 43 of Set 11 | chilca
# Processing Record 44 of Set 11 | kralendijk
# Processing Record 45 of Set 11 | florianopolis
# Processing Record 46 of Set 11 | silver city
# Processing Record 47 of Set 11 | kristinehamn
# Processing Record 48 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 49 of Set 11 | sisimiut
# Processing Record 50 of Set 11 | sur
# Processing Record 1 of Set 12 | san carlos
# Processing Record 2 of Set 12 | utete
# Processing Record 3 of Set 12 | tura
# Processing Record 4 of Set 12 | port keats
# Processing Record 5 of Set 12 | carballo
# Processing Record 6 of Set 12 | turukhansk
# Processing Record 7 of Set 12 | deputatskiy
# Processing Record 8 of Set 12 | canto do buriti
# Processing Record 9 of Set 12 | den helder
# Processing Record 10 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 12 | seymchan
# Processing Record 12 of Set 12 | sembakung
# Processing Record 13 of Set 12 | savinka
# Processing Record 14 of Set 12 | little current
# Processing Record 15 of Set 12 | kenitra
# Processing Record 16 of Set 12 | doha
# Processing Record 17 of Set 12 | listvyagi
# Processing Record 18 of Set 12 | krasnoselkup
# Processing Record 19 of Set 12 | phatthalung
# Processing Record 20 of Set 12 | nefteyugansk
# Processing Record 21 of Set 12 | college
# Processing Record 22 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 12 | itaituba
# Processing Record 24 of Set 12 | bandarbeyla
# Processing Record 25 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 12 | merauke
# Processing Record 27 of Set 12 | himora
# City not found. Skipping...
# Processing Record 28 of Set 12 | nasirabad
# Processing Record 29 of Set 12 | kitimat
# Processing Record 30 of Set 12 | gazanjyk
# Processing Record 31 of Set 12 | petit goave
# Processing Record 32 of Set 12 | halifax
# Processing Record 33 of Set 12 | inhambane
# Processing Record 34 of Set 12 | takoradi
# Processing Record 35 of Set 12 | ishigaki
# Processing Record 36 of Set 12 | nacala
# Processing Record 37 of Set 12 | fuxin
# Processing Record 38 of Set 12 | salina
# Processing Record 39 of Set 12 | oga
# Processing Record 40 of Set 12 | mae hong son
# Processing Record 41 of Set 12 | billings
# Processing Record 42 of Set 12 | filadelfia
# Processing Record 43 of Set 12 | saint-paul
# Processing Record 44 of Set 12 | council bluffs
# Processing Record 45 of Set 12 | emirdag
# Processing Record 46 of Set 12 | axim
# Processing Record 47 of Set 12 | grand-santi
# Processing Record 48 of Set 12 | arauco
# Processing Record 49 of Set 12 | warmbad
# Processing Record 50 of Set 12 | sorland
# Processing Record 1 of Set 13 | camana
# Processing Record 2 of Set 13 | panjab
# Processing Record 3 of Set 13 | saint-pierre
# Processing Record 4 of Set 13 | solnechnyy
# Processing Record 5 of Set 13 | alpena
# Processing Record 6 of Set 13 | san luis
# Processing Record 7 of Set 13 | kapit
# Processing Record 8 of Set 13 | imbituba
# Processing Record 9 of Set 13 | la asuncion
# Processing Record 10 of Set 13 | kastamonu
# Processing Record 11 of Set 13 | kostek
# Processing Record 12 of Set 13 | chardara
# Processing Record 13 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 14 of Set 13 | unye
# City not found. Skipping...
# Processing Record 15 of Set 13 | coolum beach
# Processing Record 16 of Set 13 | martapura
# Processing Record 17 of Set 13 | rio grande
# Processing Record 18 of Set 13 | puerto escondido
# Processing Record 19 of Set 13 | bjerkvik
# Processing Record 20 of Set 13 | road town
# Processing Record 21 of Set 13 | samarkand
# Processing Record 22 of Set 13 | manaus
# Processing Record 23 of Set 13 | mora
# Processing Record 24 of Set 13 | lagos
# Processing Record 25 of Set 13 | dunmore town
# Processing Record 26 of Set 13 | lasa
# Processing Record 27 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 28 of Set 13 | kangaatsiaq
# Processing Record 29 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 13 | semirom
# Processing Record 31 of Set 13 | sabratah
# Processing Record 32 of Set 13 | dalvik
# Processing Record 33 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 13 | cockburn town
# Processing Record 35 of Set 13 | charters towers
# Processing Record 36 of Set 13 | rurrenabaque
# Processing Record 37 of Set 13 | hayden
# Processing Record 38 of Set 13 | belyy yar
# Processing Record 39 of Set 13 | menongue
# Processing Record 40 of Set 13 | teahupoo
# Processing Record 41 of Set 13 | phalodi
# Processing Record 42 of Set 13 | nuristan
# Processing Record 43 of Set 13 | qaqortoq
# Processing Record 44 of Set 13 | zeya
# Processing Record 45 of Set 13 | marsh harbour
# Processing Record 46 of Set 13 | rudbar
# Processing Record 47 of Set 13 | tanah merah
# Processing Record 48 of Set 13 | santiago del estero
# Processing Record 49 of Set 13 | jitra
# Processing Record 50 of Set 13 | chiang khong
# Processing Record 1 of Set 14 | bilma
# Processing Record 2 of Set 14 | khorixas
# Processing Record 3 of Set 14 | ottumwa
# Processing Record 4 of Set 14 | okhotsk
# Processing Record 5 of Set 14 | awjilah
# Processing Record 6 of Set 14 | the valley
# Processing Record 7 of Set 14 | lalmohan
# Processing Record 8 of Set 14 | port augusta
# Processing Record 9 of Set 14 | campbell river
# Processing Record 10 of Set 14 | acajutla
# Processing Record 11 of Set 14 | san pedro
# Processing Record 12 of Set 14 | oksfjord
# Processing Record 13 of Set 14 | leh
# Processing Record 14 of Set 14 | hirara
# Processing Record 15 of Set 14 | nador
# Processing Record 16 of Set 14 | marrakesh
# Processing Record 17 of Set 14 | matara
# Processing Record 18 of Set 14 | saint-francois
# Processing Record 19 of Set 14 | shiliguri
# Processing Record 20 of Set 14 | yarkovo
# Processing Record 21 of Set 14 | garachine
# Processing Record 22 of Set 14 | bereda
# Processing Record 23 of Set 14 | arraias
# Processing Record 24 of Set 14 | ardakan
# Processing Record 25 of Set 14 | san ramon de la nueva oran
# Processing Record 26 of Set 14 | bahir dar
# Processing Record 27 of Set 14 | reconquista
# Processing Record 28 of Set 14 | mackenzie
# Processing Record 29 of Set 14 | bosaso
# Processing Record 30 of Set 14 | ayan
# Processing Record 31 of Set 14 | afyonkarahisar
# Processing Record 32 of Set 14 | dong xoai
# Processing Record 33 of Set 14 | olinda
# Processing Record 34 of Set 14 | centralia
# Processing Record 35 of Set 14 | chimbote
# Processing Record 36 of Set 14 | lexington
# Processing Record 37 of Set 14 | kroya
# Processing Record 38 of Set 14 | henties bay
# Processing Record 39 of Set 14 | darnah
# Processing Record 40 of Set 14 | revelstoke
# Processing Record 41 of Set 14 | rocha
# Processing Record 42 of Set 14 | skibbereen
# Processing Record 43 of Set 14 | fairview
# Processing Record 44 of Set 14 | quba
# Processing Record 45 of Set 14 | totskoye
# Processing Record 46 of Set 14 | taft
# Processing Record 47 of Set 14 | karang tengah
# Processing Record 48 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 14 | trairi
# Processing Record 50 of Set 14 | igrim
# Processing Record 1 of Set 15 | xuddur
# Processing Record 2 of Set 15 | alvaraes
# Processing Record 3 of Set 15 | suleja
# Processing Record 4 of Set 15 | slavonice
# Processing Record 5 of Set 15 | dunedin
# Processing Record 6 of Set 15 | yertsevo
# Processing Record 7 of Set 15 | tucurui
# Processing Record 8 of Set 15 | togur
# Processing Record 9 of Set 15 | marawi
# Processing Record 10 of Set 15 | hamilton
# Processing Record 11 of Set 15 | joao camara
# Processing Record 12 of Set 15 | viedma
# Processing Record 13 of Set 15 | karratha
# Processing Record 14 of Set 15 | beringovskiy
# Processing Record 15 of Set 15 | linping
# Processing Record 16 of Set 15 | patan
# Processing Record 17 of Set 15 | san patricio
# Processing Record 18 of Set 15 | broadstairs
# Processing Record 19 of Set 15 | sergeyevka
# Processing Record 20 of Set 15 | kholmogory
# Processing Record 21 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 22 of Set 15 | dedza
# Processing Record 23 of Set 15 | alamogordo
# Processing Record 24 of Set 15 | sohag
# Processing Record 25 of Set 15 | paka
# Processing Record 26 of Set 15 | sadiqabad
# Processing Record 27 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 15 | tual
# Processing Record 29 of Set 15 | umm kaddadah
# Processing Record 30 of Set 15 | ouidah
# Processing Record 31 of Set 15 | cayenne
# Processing Record 32 of Set 15 | ambon
# Processing Record 33 of Set 15 | trinidad
# Processing Record 34 of Set 15 | mantua
# Processing Record 35 of Set 15 | itarema
# Processing Record 36 of Set 15 | becerril
# Processing Record 37 of Set 15 | khandyga
# Processing Record 38 of Set 15 | guiyang
# Processing Record 39 of Set 15 | rio bananal
# Processing Record 40 of Set 15 | turayf
# Processing Record 41 of Set 15 | puerto madryn
# Processing Record 42 of Set 15 | buluang
# Processing Record 43 of Set 15 | umm lajj
# Processing Record 44 of Set 15 | valdivia
# Processing Record 45 of Set 15 | ruy barbosa
# Processing Record 46 of Set 15 | kigoma
# Processing Record 47 of Set 15 | linhares
# Processing Record 48 of Set 15 | odienne
# Processing Record 49 of Set 15 | porto de moz
# Processing Record 50 of Set 15 | kenai
# Processing Record 1 of Set 16 | pochutla
# Processing Record 2 of Set 16 | neyshabur
# Processing Record 3 of Set 16 | sinesti
# Processing Record 4 of Set 16 | pecos
# Processing Record 5 of Set 16 | hrubieszow
# Processing Record 6 of Set 16 | byron bay
# Processing Record 7 of Set 16 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 16 | gat
# Processing Record 9 of Set 16 | puerto del rosario
# Processing Record 10 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 16 | mwene-ditu
# Processing Record 12 of Set 16 | pacific grove
# Processing Record 13 of Set 16 | ginir
# Processing Record 14 of Set 16 | katesh
# Processing Record 15 of Set 16 | norwich
# Processing Record 16 of Set 16 | trabzon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 713

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Adrar  20.5022  -10.0711     89.10        32          93
# 1    Puerto Ayora  -0.7393  -90.3518     65.55        92          85
# 2  Port Macquarie -31.4333  152.9167     62.89        61           4
# 3           Colac -38.3333  143.5833     56.08        60          92
# 4           Kieta  -6.2167  155.6333     85.62        62          28
# 5       Bathsheba  13.2167  -59.5167     79.41        94          40
# 6      Letlhakane -21.4167   25.5833     68.74        30           0
# 7      Sao Filipe  14.8961  -24.4956     78.06        71          69
# 8          Hobart -42.8794  147.3294     57.25        74          75
# 9           Vaini -21.2000 -175.2000     77.16        78          75
#
#    Wind Speed Country Current Description
# 0        7.31      MR          light rain
# 1        5.01      EC     overcast clouds
# 2        7.31      AU           clear sky
# 3        2.64      AU     overcast clouds
# 4        4.83      PG    scattered clouds
# 5        5.75      BB          light rain
# 6        8.77      BW           clear sky
# 7        7.61      CV       broken clouds
# 8        8.05      AU       broken clouds
# 9        8.05      TO       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Adrar      MR  20.5022  -10.0711     89.10        32          93
# 1    Puerto Ayora      EC  -0.7393  -90.3518     65.55        92          85
# 2  Port Macquarie      AU -31.4333  152.9167     62.89        61           4
# 3           Colac      AU -38.3333  143.5833     56.08        60          92
# 4           Kieta      PG  -6.2167  155.6333     85.62        62          28
#
#    Wind Speed Current Description
# 0        7.31          light rain
# 1        5.01     overcast clouds
# 2        7.31           clear sky
# 3        2.64     overcast clouds
# 4        4.83    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
